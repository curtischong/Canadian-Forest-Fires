# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import shapefile as shp
import pandas as pd
import math

# %%
final_features_df = pd.read_pickle("final_features_df")

# %%
final_features_df.head()
# Out:
#     fire_id  size_ha  temp precipitation wind_speed month  burn_rate
# 0    EWF008     0.04   9.2       -9999.9        NaN     4        1.0
# 1    EWF002     0.20   9.2       -9999.9        NaN     4        1.0
# 65   PWF035     0.20  18.1       -9999.9    -9999.9     6        1.0
# 114  PWF034     0.50  18.1       -9999.9    -9999.9     6        1.0
# 115  CWF010     0.01  13.6       -9999.9        NaN     5        1.0

# %%
final_features_df = final_features_df.convert_objects(convert_numeric=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
final_features_df = final_features_df[pd.notnull(final_features_df['wind_speed'])]
final_features_df = final_features_df[pd.notnull(final_features_df['temp'])]
final_features_df = final_features_df[pd.notnull(final_features_df['size_ha'])]
final_features_df = final_features_df[pd.notnull(final_features_df['month'])]
final_features_df = final_features_df[pd.notnull(final_features_df['burn_rate'])]
final_features_df = final_features_df.dropna()

# %%
final_features_df = final_features_df[final_features_df["wind_speed"] != -9999.9]
final_features_df = final_features_df[final_features_df["precipitation"] != -9999.9]
final_features_df = final_features_df[final_features_df["temp"] != -9999.9]
final_features_df = final_features_df[final_features_df["size_ha"] != -1]

# %%
final_features_df.head()
# Out:
#         fire_id  size_ha  temp  precipitation  wind_speed  month  burn_rate
# 131774  10011.0   294.00 -20.2           25.8        14.1      0        1.0
# 131775  22004.0   245.34  11.2           52.3        11.1      5        1.0
# 131780  45000.0  1036.00  11.9           76.3        11.0      7        1.0
# 131781  62006.0  1024.70  12.0           68.4        12.8      7        1.0
# 239734   1814.0     0.01   4.8           59.2        13.5      8        1.0

# %%
final_features_df.dtypes
# Out:
# fire_id          float64
# size_ha          float64
# temp             float64
# precipitation    float64
# wind_speed       float64
# month              int64
# burn_rate        float64
# dtype: object

# %%
plt.scatter(final_features_df['size_ha'], final_features_df['temp'], s=1)
plt.ylabel('temp')
plt.xlabel('size_ha')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['size_ha'], final_features_df['precipitation'], s=1)
plt.ylabel('precipitation')
plt.xlabel('size_ha')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['size_ha'], final_features_df['wind_speed'], s=1)
plt.ylabel('wind_speed')
plt.xlabel('size_ha')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['size_ha'], final_features_df['month'], s=1)
plt.ylabel('month')
plt.xlabel('size_ha')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['size_ha'], final_features_df['burn_rate'], s=1)
plt.ylabel('burn_rate')
plt.xlabel('size_ha')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['temp'], final_features_df['precipitation'], s=1)
plt.ylabel('precipitation')
plt.xlabel('temp')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['temp'], final_features_df['wind_speed'], s=1)
plt.ylabel('wind_speed')
plt.xlabel('temp')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['temp'], final_features_df['month'], s=1)
plt.ylabel('month')
plt.xlabel('temp')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['temp'], final_features_df['burn_rate'], s=1)
plt.ylabel('burn_rate')
plt.xlabel('temp')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['precipitation'], final_features_df['wind_speed'], s=1)
plt.ylabel('wind_speed')
plt.xlabel('precipitation')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['precipitation'], final_features_df['month'], s=1)
plt.ylabel('month')
plt.xlabel('precipitation')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['precipitation'], final_features_df['burn_rate'], s=1)
plt.ylabel('burn_rate')
plt.xlabel('precipitation')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['wind_speed'], final_features_df['month'], s=1)
plt.ylabel('month')
plt.xlabel('wind_speed')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['wind_speed'], final_features_df['burn_rate'], s=1)
plt.ylabel('burn_rate')
plt.xlabel('wind_speed')
plt.show()
plt.rcParams['savefig.dpi'] = 500

# %%
plt.scatter(final_features_df['month'], final_features_df['burn_rate'], s=1)
plt.ylabel('burn_rate')
plt.xlabel('month')
plt.show()
plt.rcParams['savefig.dpi'] = 500
